# %%
import easyocr

# %%
reader = easyocr.Reader(['en'], gpu = False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL
from PIL import ImageDraw

# %%
im = PIL.Image.open('1.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078160>

# %%
im2 = PIL.Image.open('2.png')
im2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078048>

# %%
im3 = PIL.Image.open('3.png')
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078E80>

# %%
im4 = PIL.Image.open('4.png')
im4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078EB8>

# %%
im5 = PIL.Image.open('5.png')
im5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D5090BA0B8>

# %%
bounds = reader.readtext('1.png')
bounds
# Out:
# [([[47, 113], [156, 113], [156, 157], [47, 157]], 'Selva', 0.8262410474841979),
#  ([[52, 158], [278, 158], [278, 190], [52, 190]],
#   'DATA MANAGER',
#   0.998914111021849),
#  ([[120, 224], [333, 224], [333, 254], [120, 254]],
#   '+123-456-7890',
#   0.5042700821712609),
#  ([[120, 262], [330, 262], [330, 294], [120, 294]],
#   '+123-456-7891',
#   0.9871488272689672),
#  ([[120, 318], [340, 318], [340, 350], [120, 350]],
#   'WWW XYZI.com',
#   0.5777974826987659),
#  ([[119, 355], [359, 355], [359, 391], [119, 391]],
#   'hello@XYZ1.com',
#   0.8762188441024716),
#  ([[121, 410], [411, 410], [411, 447], [121, 447]],
#   '123 ABC St , Chennai;',
#   0.49302537842785377),
#  ([[725, 388], [908, 388], [908, 463], [725, 463]],
#   'selva',
#   0.9999268555996703),
#  ([[119, 445], [379, 445], [379, 481], [119, 481]],
#   'TamilNadu 600113',
#   0.9349834186667286),
#  ([[694, 477], [942, 477], [942, 565], [694, 565]],
#   'digitals',
#   0.9513100019868355)]

# %%
bounds2 = reader.readtext('2.png')
bounds2
# Out:
# [([[126, 126], [402, 126], [402, 178], [126, 178]],
#   'Amit kumar',
#   0.8217942874933861),
#  ([[125, 193], [393, 193], [393, 229], [125, 229]],
#   'CEO & FOUNDER',
#   0.9981912706287305),
#  ([[172, 278], [342, 278], [342, 310], [172, 310]],
#   '123-456-7569',
#   0.7599104170013044),
#  ([[169, 331], [411, 331], [411, 371], [169, 371]],
#   'hello@global.com',
#   0.9452339762649525),
#  ([[168, 388], [240, 388], [240, 412], [168, 412]], 'WWW', 0.9990257007900342),
#  ([[241, 381], [393, 381], [393, 419], [241, 419]],
#   'global.com',
#   0.6216657157993554),
#  ([[167, 428], [308, 428], [308, 472], [167, 472]],
#   '123 global',
#   0.9800736408880154),
#  ([[349, 427], [449, 427], [449, 472], [349, 472]],
#   'Erode,',
#   0.8696429332917907),
#  ([[651, 410], [930, 410], [930, 484], [651, 484]],
#   'GLOBAL',
#   0.9999419399037105),
#  ([[166, 472], [416, 472], [416, 504], [166, 504]],
#   'TamilNadu 600115',
#   0.9995963104120076),
#  ([[590, 505], [986, 505], [986, 573], [590, 573]],
#   'INSURANCE',
#   0.8423243502142476),
#  ([[305.1299778141514, 431.1289267866996],
#    [354.76594631682207, 438.8383025469347],
#    [349.8700221858486, 469.8710732133004],
#    [299.23405368317793, 462.1616974530653]],
#   'St ,',
#   0.5235604643821716)]

# %%
bounds3 = reader.readtext('3.png')
bounds3
# Out:
# [([[466, 62], [718, 62], [718, 112], [466, 112]],
#   'KARTHICK',
#   0.9999798115751519),
#  ([[481, 114], [741, 114], [741, 156], [481, 156]],
#   'General Manager',
#   0.8600230114652667),
#  ([[576, 187], [803, 187], [803, 220], [576, 220]],
#   '123 ABC St , Salem,',
#   0.9104906577284684),
#  ([[574, 220], [814, 220], [814, 250], [574, 250]],
#   'TamilNadu 6004513',
#   0.7656378565732854),
#  ([[564, 266], [768, 266], [768, 298], [564, 298]],
#   '+123-456-7890',
#   0.6565492910016496),
#  ([[598, 318], [864, 318], [864, 350], [598, 350]],
#   'hello@Borcelle.com',
#   0.9531449571013404),
#  ([[598, 371], [847, 371], [847, 403], [598, 403]],
#   'www Borcelle.com',
#   0.5453896188359569),
#  ([[78, 446], [340, 446], [340, 496], [78, 496]],
#   'BORCELLE',
#   0.9946699938296841),
#  ([[81, 511], [319, 511], [319, 561], [81, 561]],
#   'AIRLINES',
#   0.9910951152257645)]

# %%
bounds4 = reader.readtext('4.png')
bounds4
# Out:
# [([[718, 62], [1000, 62], [1000, 122], [718, 122]],
#   'REVANTH',
#   0.9999861675080858),
#  ([[626, 129], [976, 129], [976, 184], [626, 184]],
#   'Marketing Executive',
#   0.7983423178785621),
#  ([[465, 287], [911, 287], [911, 323], [465, 323]],
#   '123 ABC St,, HYDRABAD, TamilNadu;',
#   0.714040987833879),
#  ([[640, 324], [732, 324], [732, 354], [640, 354]],
#   '600001',
#   0.9999874438992078),
#  ([[669, 361], [895, 361], [895, 397], [669, 397]],
#   '+91-456-1234',
#   0.9757989135063242),
#  ([[503, 427], [883, 427], [883, 465], [503, 465]],
#   'hello@CHRISTMAS.com',
#   0.7404252194048071),
#  ([[91, 417], [321, 417], [321, 516], [91, 516]],
#   'Family',
#   0.8405842363412932),
#  ([[525, 495], [885, 495], [885, 533], [525, 533]],
#   'wWW.CHRISTMAS.com',
#   0.7820481365365869),
#  ([[26, 518], [392, 518], [392, 590], [26, 590]],
#   'Restaurant',
#   0.9964809393504941)]

# %%
bounds5 = reader.readtext('5.png')
bounds5
# Out:
# [([[26, 87], [325, 87], [325, 143], [26, 143]], 'SANTHOSH', 0.999970581320496),
#  ([[42, 147], [343, 147], [343, 198], [42, 198]],
#   'Technical Manager',
#   0.8029191324832127),
#  ([[102, 259], [459, 259], [459, 291], [102, 291]],
#   '123 ABC St , Tirupur; TamilNadu,',
#   0.5089519537578897),
#  ([[236, 292], [324, 292], [324, 320], [236, 320]],
#   '641603',
#   0.5335995383673531),
#  ([[112, 315], [310, 315], [310, 348], [112, 348]],
#   '+123-456-1234',
#   0.9398779858497522),
#  ([[176, 368], [383, 368], [383, 408], [176, 408]],
#   'hello@Sun.com',
#   0.8816454897034561),
#  ([[178, 426], [364, 426], [364, 454], [178, 454]],
#   'www.Suncom',
#   0.6482863777232087),
#  ([[506, 492], [1000, 492], [1000, 568], [506, 568]],
#   'Sun Electricals',
#   0.7447944253459663)]

# %%
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0,p1,p2,p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D50650D240>

# %%
draw_boxes(im2, bounds2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078048>

# %%
draw_boxes(im3, bounds3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078E80>

# %%
draw_boxes(im4, bounds4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D509078EB8>

# %%
draw_boxes(im5, bounds5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1004x590 at 0x1D5090BA0B8>

# %%
len(bounds)
# Out:
# 10

# %%
len(bounds2)
# Out:
# 12

# %%
len(bounds3)
# Out:
# 9

# %%
len(bounds4)
# Out:
# 9

# %%
len(bounds5)
# Out:
# 8

# %%
for i in bounds:
    print(i[1])
# Out:
# Selva
# DATA MANAGER
# +123-456-7890
# +123-456-7891
# WWW XYZI.com
# hello@XYZ1.com
# 123 ABC St , Chennai;
# selva
# TamilNadu 600113
# digitals

# %%
for i in bounds2:
    print(i[1])
# Out:
# Amit kumar
# CEO & FOUNDER
# 123-456-7569
# hello@global.com
# WWW
# global.com
# 123 global
# Erode,
# GLOBAL
# TamilNadu 600115
# INSURANCE
# St ,

# %%
for i in bounds3:
    print(i[1])
# Out:
# KARTHICK
# General Manager
# 123 ABC St , Salem,
# TamilNadu 6004513
# +123-456-7890
# hello@Borcelle.com
# www Borcelle.com
# BORCELLE
# AIRLINES

# %%
for i in bounds4:
    print(i[1])
# Out:
# REVANTH
# Marketing Executive
# 123 ABC St,, HYDRABAD, TamilNadu;
# 600001
# +91-456-1234
# hello@CHRISTMAS.com
# Family
# wWW.CHRISTMAS.com
# Restaurant

# %%
for i in bounds5:
    print(i[1])
# Out:
# SANTHOSH
# Technical Manager
# 123 ABC St , Tirupur; TamilNadu,
# 641603
# +123-456-1234
# hello@Sun.com
# www.Suncom
# Sun Electricals

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-1.1.5-cp36-cp36m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\bittu\anaconda3\envs\env_easyocr\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\bittu\anaconda3\envs\env_easyocr\lib\site-packages (from pandas) (1.19.2)
# Collecting pytz>=2017.2
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# Requirement already satisfied: six>=1.5 in c:\users\bittu\anaconda3\envs\env_easyocr\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.1.5 pytz-2022.7.1

# %%
import pandas as pd

# %%
pd.DataFrame(bounds, columns = ['coordinates', 'words', 'confidence interval'])
# Out:
#                                         coordinates                  words  \
# 0    [[47, 113], [156, 113], [156, 157], [47, 157]]                  Selva
# 1    [[52, 158], [278, 158], [278, 190], [52, 190]]           DATA MANAGER
# 2  [[120, 224], [333, 224], [333, 254], [120, 254]]          +123-456-7890
# 3  [[120, 262], [330, 262], [330, 294], [120, 294]]          +123-456-7891
# 4  [[120, 318], [340, 318], [340, 350], [120, 350]]           WWW XYZI.com
# 5  [[119, 355], [359, 355], [359, 391], [119, 391]]         hello@XYZ1.com
# 6  [[121, 410], [411, 410], [411, 447], [121, 447]]  123 ABC St , Chennai;
# 7  [[725, 388], [908, 388], [908, 463], [725, 463]]                  selva
# 8  [[119, 445], [379, 445], [379, 481], [119, 481]]       TamilNadu 600113
# 9  [[694, 477], [942, 477], [942, 565], [694, 565]]               digitals
#
#    confidence interval
# 0             0.826241
# 1             0.998914
# 2             0.504270
# 3             0.987149
# 4             0.577797
# 5             0.876219
# 6             0.493025
# 7             0.999927
# 8             0.934983
# 9             0.951310

# %%
pd.DataFrame(bounds2, columns = ['coordinates', 'words', 'confidence interval'])
# Out:
#                                           coordinates             words  \
# 0    [[126, 126], [402, 126], [402, 178], [126, 178]]        Amit kumar
# 1    [[125, 193], [393, 193], [393, 229], [125, 229]]     CEO & FOUNDER
# 2    [[172, 278], [342, 278], [342, 310], [172, 310]]      123-456-7569
# 3    [[169, 331], [411, 331], [411, 371], [169, 371]]  hello@global.com
# 4    [[168, 388], [240, 388], [240, 412], [168, 412]]               WWW
# 5    [[241, 381], [393, 381], [393, 419], [241, 419]]        global.com
# 6    [[167, 428], [308, 428], [308, 472], [167, 472]]        123 global
# 7    [[349, 427], [449, 427], [449, 472], [349, 472]]            Erode,
# 8    [[651, 410], [930, 410], [930, 484], [651, 484]]            GLOBAL
# 9    [[166, 472], [416, 472], [416, 504], [166, 504]]  TamilNadu 600115
# 10   [[590, 505], [986, 505], [986, 573], [590, 573]]         INSURANCE
# 11  [[305.1299778141514, 431.1289267866996], [354....              St ,
#
#     confidence interval
# 0              0.821794
# 1              0.998191
# 2              0.759910
# 3              0.945234
# 4              0.999026
# 5              0.621666
# 6              0.980074
# 7              0.869643
# 8              0.999942
# 9              0.999596
# 10             0.842324
# 11             0.523560

# %%
pd.DataFrame(bounds3, columns = ['coordinates', 'words', 'confidence interval'])
# Out:
#                                         coordinates                words  \
# 0    [[466, 62], [718, 62], [718, 112], [466, 112]]             KARTHICK
# 1  [[481, 114], [741, 114], [741, 156], [481, 156]]      General Manager
# 2  [[576, 187], [803, 187], [803, 220], [576, 220]]  123 ABC St , Salem,
# 3  [[574, 220], [814, 220], [814, 250], [574, 250]]    TamilNadu 6004513
# 4  [[564, 266], [768, 266], [768, 298], [564, 298]]        +123-456-7890
# 5  [[598, 318], [864, 318], [864, 350], [598, 350]]   hello@Borcelle.com
# 6  [[598, 371], [847, 371], [847, 403], [598, 403]]     www Borcelle.com
# 7    [[78, 446], [340, 446], [340, 496], [78, 496]]             BORCELLE
# 8    [[81, 511], [319, 511], [319, 561], [81, 561]]             AIRLINES
#
#    confidence interval
# 0             0.999980
# 1             0.860023
# 2             0.910491
# 3             0.765638
# 4             0.656549
# 5             0.953145
# 6             0.545390
# 7             0.994670
# 8             0.991095

# %%
pd.DataFrame(bounds4, columns = ['coordinates', 'words', 'confidence interval'])
# Out:
#                                         coordinates  \
# 0  [[718, 62], [1000, 62], [1000, 122], [718, 122]]
# 1  [[626, 129], [976, 129], [976, 184], [626, 184]]
# 2  [[465, 287], [911, 287], [911, 323], [465, 323]]
# 3  [[640, 324], [732, 324], [732, 354], [640, 354]]
# 4  [[669, 361], [895, 361], [895, 397], [669, 397]]
# 5  [[503, 427], [883, 427], [883, 465], [503, 465]]
# 6    [[91, 417], [321, 417], [321, 516], [91, 516]]
# 7  [[525, 495], [885, 495], [885, 533], [525, 533]]
# 8    [[26, 518], [392, 518], [392, 590], [26, 590]]
#
#                                words  confidence interval
# 0                            REVANTH             0.999986
# 1                Marketing Executive             0.798342
# 2  123 ABC St,, HYDRABAD, TamilNadu;             0.714041
# 3                             600001             0.999987
# 4                       +91-456-1234             0.975799
# 5                hello@CHRISTMAS.com             0.740425
# 6                             Family             0.840584
# 7                  wWW.CHRISTMAS.com             0.782048
# 8                         Restaurant             0.996481

# %%
pd.DataFrame(bounds5, columns = ['coordinates', 'words', 'confidence interval'])
# Out:
#                                          coordinates  \
# 0       [[26, 87], [325, 87], [325, 143], [26, 143]]
# 1     [[42, 147], [343, 147], [343, 198], [42, 198]]
# 2   [[102, 259], [459, 259], [459, 291], [102, 291]]
# 3   [[236, 292], [324, 292], [324, 320], [236, 320]]
# 4   [[112, 315], [310, 315], [310, 348], [112, 348]]
# 5   [[176, 368], [383, 368], [383, 408], [176, 408]]
# 6   [[178, 426], [364, 426], [364, 454], [178, 454]]
# 7  [[506, 492], [1000, 492], [1000, 568], [506, 5...
#
#                               words  confidence interval
# 0                          SANTHOSH             0.999971
# 1                 Technical Manager             0.802919
# 2  123 ABC St , Tirupur; TamilNadu,             0.508952
# 3                            641603             0.533600
# 4                     +123-456-1234             0.939878
# 5                     hello@Sun.com             0.881645
# 6                        www.Suncom             0.648286
# 7                   Sun Electricals             0.744794
